# %% [markdown]
# 컴퓨터과학과 202310940 송혜주

# %% [markdown]
# 1. Make a triangle signal with frequency 440 and make a Wave with duration 0.01 seconds. Plot the waveform.

# %%
from thinkdsp import TriangleSignal
from thinkdsp import decorate

#주파수 440의 삼각형 신호
signal = TriangleSignal(freq = 440)

#지속 시간 0.01초 웨이브
wave = signal.make_wave(duration = 0.01)

#파형 플로팅
wave.plot()
decorate(xlabel='Time(s)')

# %% [markdown]
# 2. Make a Spectrum object and print spectrum.hs[0]. What is the amplitude and phase of this component?
#
# 답: 진폭은 복소수의 크기로 1.0436096431476471e-14이고 위상은 복소수의 각도로 0이다

# %%
spectrum = wave.make_spectrum()
print(spectrum.hs[0])
# Out:
# (1.0436096431476471e-14+0j)

# %% [markdown]
# 3. Set spectrum.hs[0] = 100. Make a Wave from the modified Spectrum and plot it. What effect does this operation have on the waveform?

# %%
spectrum.hs[0] = 100
modifiedWave = spectrum.make_wave()
modifiedWave.plot()

# %% [markdown]
# 전체 파형이 위로 약 1.00 만큼 이동한다
